# %%
import functions as F

# %%
def plot_loss(name,loss_epoch):
    
    import matplotlib.pyplot as plt
    file='Model/loss_mean'+name
    print(file)
    data=F.load_to_file(file)
    plt.plot(range(len(data)),data)
    plt.show()
#     print(data[0])

# %%
plot_loss("sigmoid_learn0.1_F",200)
plot_loss("tanh_learn0.1_F",200)
plot_loss("plane0.1_F",200)
plot_loss("Relu0.1_F",200)
plot_loss("sigmoid_learn0.1_T",200)
# plot_loss("tanh_learn0.1_T",200)
# plot_loss("plane0.1_T",200)
# plot_loss("Relu0.1_T",200)
# Out:
# Model/loss_meansigmoid_learn0.1_F
# Model/loss_meantanh_learn0.1_F
# Model/loss_meanplane0.1_F
# Model/loss_meanRelu0.1_F
# Model/loss_meansigmoid_learn0.1_T
